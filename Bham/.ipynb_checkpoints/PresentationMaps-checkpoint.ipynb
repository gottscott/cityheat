# %%
# Import data and libraries
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd
import matplotlib
import matplotlib.pylab as pylab
from mpl_toolkits.basemap import Basemap
pylab.rcParams['figure.figsize'] = 16, 12
pd.options.display.mpl_style = 'default'
get_ipython().magic(u'matplotlib inline')
import sys 

sys.path.append('../Bmore/')
#import ibuttonplots
import importibuttondata
#%matplotlib inline

files = glob.glob('./data/olddata/*[tT].csv')
meta0 = pd.DataFrame(pd.read_csv('./data/birminghammeta_cleaned.csv', sep = ','))
tempDF, anomalyDF, meta = importibuttondata.importdata(files, meta0)

# %%
matplotlib.rcParams.update({'font.size': 22})

# %%
# Import data and libraries
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd
import matplotlib
import matplotlib.pylab as pylab
from mpl_toolkits.basemap import Basemap
pylab.rcParams['figure.figsize'] = 16, 12
pd.options.display.mpl_style = 'default'
get_ipython().magic(u'matplotlib inline')
import sys 

sys.path.append('../Bmore/')
import ibuttonplots
import importibuttondata
# %matplotlib inline

files = glob.glob('/data/olddata/*[tT].csv')
meta0  = pd.DataFrame(pd.read_csv('./data/birminghammeta_cleaned.csv', sep = ','))
tempDF0, anomalyDF0, meta0 = importibuttondata.importdata(files, meta0)

files = glob.glob('/data/*[tT].csv')
#files = glob.glob('./data/*[tT].csv')
meta1 = pd.DataFrame(pd.read_csv('./data/birminghammetanew.csv', sep = ','))

#meta0 = pd.DataFrame(pd.read_csv('./data/bmoremetadata.csv', sep = ','))
tempDF1, anomalyDF1, meta1 = importibuttondata.importdata(files, meta1)

frames = [tempDF0, tempDF1]
tempDF = pd.concat(frames)
anomalyDF = pd.concat([anomalyDF0, anomalyDF1])
meta = pd.concat([meta0, meta1.loc()[np.setdiff1d(meta1.sensornumber, meta0.sensornumber)]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8803a2e9c52d> in <module>()
#      20 files = glob.glob('/data/olddata/*[tT].csv')
#      21 meta0  = pd.DataFrame(pd.read_csv('./data/birminghammeta_cleaned.csv', sep = ','))
# ---> 22 tempDF0, anomalyDF0, meta0 = importibuttondata.importdata(files, meta0)
#      23
#      24 files = glob.glob('/data/*[tT].csv')
#
# /Users/ascott47/blausteinmount/git/cityheat/Bmore/importibuttondata.py in importdata(files, meta)
#      55                 print "oops... something went wrong"
#      56
# ---> 57         tempDF = pd.concat(frames, axis =1).resample('H')
#      58         #tempDF = pd.concat(frames, axis =1).resample('H').dropna()
#      59         meta = meta.loc[np.intersect1d(tempDF.columns.values, meta.sensornumber.values)]
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     752                        keys=keys, levels=levels, names=names,
#     753                        verify_integrity=verify_integrity,
# --> 754                        copy=copy)
#     755     return op.get_result()
#     756
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     797
#     798         if len(objs) == 0:
# --> 799             raise ValueError('All objects passed were None')
#     800
#     801         # consolidate data & figure out what our result ndim is going to be
#
# ValueError: All objects passed were None

# %%
m.fillcontinents(color = '#f0f0f0', zorder =0 )
m.drawmapboundary(fill_color='#a6bddb')
#m.drawmapboundary(zorder=0)
m.drawcoastlines(zorder=0)
m.drawstates(zorder=1)
m.drawcounties()
m.plot(x,y,'*', markersize=10, color = 'gray')

# %%
x = meta['location:Longitude'].values
y = meta['location:Latitude'].values
c = tempDF.mean(axis=0).values # The colors will show the mean temp at that location
marker_size = 150
fig = plt.figure(figsize=(10,10))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

m = Basemap(llcrnrlon=meta['location:Longitude'].min()-1,
            llcrnrlat=meta['location:Latitude'].min()-1.75,
            urcrnrlon=meta['location:Longitude'].max()+2,
            urcrnrlat=meta['location:Latitude'].max()+1.75,
            projection='mill',
            resolution ='h',
            #area_thresh=1000.
            )
m.fillcontinents(color = '#f0f0f0', zorder =0 )
m.drawmapboundary(fill_color='#a6bddb')
#m.drawmapboundary(zorder=0)
m.drawcoastlines(zorder=0)
m.drawstates(zorder=1)
m.drawcounties()

#celsius = m.scatter(x,y, s = marker_size, c = c[:], cmap = matplotlib.cm.RdBu_r, latlon = True)
#cbar1 = m.colorbar(celsius, location = 'right', label = 'Temperature in $^\circ $C')

#fahr = m.scatter(x,y, s = marker_size, c =(c[:]*9./5. + 32.), cmap = matplotlib.cm.RdBu_r, latlon = True)
#cbar2 = m.colorbar(fahr, location = 'bottom', label = 'Temperature in $^\circ $F')
cmap = matplotlib.cm.OrRd
bounds = np.linspace(78,82, 5)
#bounds = np.linspace(round((c.mean()-3)*9/5.+32),round((c.mean()+3)*9/5.+32),7)
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)

fahr = m.scatter(x,y, s = marker_size, c =(c*9./5. + 32.),
                     cmap = cmap,
                     norm = norm,
                     #cmap = matplotlib.cm.RdBu_r,
                        latlon = True,
                        lw = 2,
                        edgecolor = 'gray',
                        #vmin = (c.mean()-3)*9/5.,
                        #vmax = (c.mean()+3)*9/5.,
                        )
cbar2 = m.colorbar(fahr, location = 'bottom', label = 'Temperature in $^\circ $F')
cbar2.ax.set_xticks([78,79, 80,81,82])
cbar2.ax.set_xticklabels(['78', '79', '80', '81', '82'])
matplotlib.rcParams.update({'font.size': 22})

lons =  -86.281743
lats = 32.352500
label = 'Montgomery'
x,y = m(lons,lats)
m.plot(x,y,'*', markersize=10, color = 'gray')
#plt.text(x,y,label)
plt.title('Thermometer Locations')
plt.savefig('./plots/bigmap.eps', format = 'eps', dpi = 600)

# %%
def mapmean_fahr(tempDF, meta, name = '', mincolor = 78, maxcolor= 82):
    fig  = plt.figure(figsize=(10, 10))
    x = meta['location:Longitude'].values
    y = meta['location:Latitude'].values
    c = tempDF.mean(axis=0).values # The colors will show the mean temp at that location
    marker_size = 150
    #fig = plt.figure(figsize=(10,10))
    ax = fig.add_axes([0.1,0.1,0.8,0.8])

    m = Basemap(llcrnrlon=meta['location:Longitude'].min()-.05,
                llcrnrlat=meta['location:Latitude'].min()-.05,
                urcrnrlon=meta['location:Longitude'].max()+.05,
                urcrnrlat=meta['location:Latitude'].max()+.05,
                projection='mill',
                #projection = 'merc',
                resolution ='h',
                #area_thresh=1000.
                epsg=3857
                )
    wms_server = "http://osm.woc.noaa.gov/mapcache"
    m.wmsimage(wms_server, layers = ["osm"], verbose = False)
    m.drawcounties()

    #define the color map
    cmap = matplotlib.cm.OrRd
    bounds = np.linspace(mincolor,maxcolor, 5)
    #bounds = np.linspace(round((c.mean()-3)*9/5.+32),round((c.mean()+3)*9/5.+32),5)
    norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)
 
    fahr = m.scatter(x,y, s = marker_size, c =(c*9./5. + 32.),
                     cmap = cmap,
                     norm = norm,
                     #cmap = matplotlib.cm.RdBu_r,
                        latlon = True,
                        lw = 2,
                        edgecolor = 'gray',
                        #vmin = (c.mean()-3)*9/5.,
                        #vmax = (c.mean()+3)*9/5.,
                        )

    cbar2 = m.colorbar(fahr, location = 'bottom', label = 'Temperature in $^\circ $F')

    lon = x[c.argmin()]
    lat = y[c.argmin()]
    a,b = m(lon,lat)
    plt.text(a,b, '%2.1f'%(c.min()*9/5.+32),
             ha = 'center',
             va = 'bottom',
             fontsize=16,
             #fontweight='bold',
             color = 'k')

    lon = x[c.argmax()]
    lat = y[c.argmax()]
    a,b = m(lon,lat)
    plt.text(a,b, '%2.1f'%(c.max()*9/5.+32),
             ha = 'center',
             va = 'bottom',
             fontsize=18,
             #fontweight='bold',
             color = 'k')

    plt.title('Mean Temperature %s'%name)

    filename = './plots/meantempmap%sFahr.eps'%name
    plt.savefig(filename, format = 'eps', dpi = 600)

# %%
#import sys
#sys.path.append('../Bmore/')
#import ibuttonplots
#import importibuttondata

Birmingham = np.where(meta['location:Latitude'] > 33)
Wilcox = np.where(meta['location:Latitude'] < 33)
BirminghamSensors = meta['sensornumber'].values[Birmingham]
WilcoxSensors = meta['sensornumber'].values[Wilcox]

# %%
mapmean_fahr(tempDF[WilcoxSensors], meta.loc()[WilcoxSensors], 'Wilcox County')
mapmean_fahr(tempDF[WilcoxSensors][tempDF.index.hour == 6], meta.loc()[WilcoxSensors], 'Wilcox County 6am')
mapmean_fahr(tempDF[WilcoxSensors][tempDF.index.hour == 16], meta.loc()[WilcoxSensors], 'Wilcox County 4pm')
#plt.savefig('meanwilcox.eps', format = 'eps', dpi = 600)

# %%
mapmean_fahr(tempDF[BirminghamSensors], meta.loc()[BirminghamSensors], 'Birmingham')

# %%
max(tempDF[BirminghamSensors][tempDF.index.hour == 6].mean()*9/5.+32), min(tempDF[BirminghamSensors][tempDF.index.hour == 6].mean()*9/5.+32)
# Out:
# (76.634149999999991, 70.918873684210524)

# %%
mapmean_fahr(tempDF[BirminghamSensors][tempDF.index.hour == 6], meta.loc()[BirminghamSensors], 'Birmingham 6am',  mincolor = 70, maxcolor = 78)

# %%
max(tempDF[BirminghamSensors][tempDF.index.hour == 16].mean()*9/5.+32), min(tempDF[BirminghamSensors][tempDF.index.hour == 16].mean()*9/5.+32)
# Out:
# (93.103389380530956, 84.488932142857138)

# %%
mapmean_fahr(tempDF[BirminghamSensors][tempDF.index.hour == 16], meta.loc()[BirminghamSensors], 'Birmingham 4pm', mincolor = 85, maxcolor = 93)

# %%
Birmingham = np.where(meta['location:Latitude'] > 33)
Wilcox = np.where(meta['location:Latitude'] < 33)
BirminghamSensors = meta['sensornumber'].values[Birmingham]
WilcoxSensors = meta['sensornumber'].values[Wilcox]
fig  = plt.figure(figsize=(15, 10))
tempDF[WilcoxSensors].mean(axis=1).plot(label = 'Wilcox County Average')
tempDF[BirminghamSensors].mean(axis=1).plot(label = 'Birmingham Average')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
def diurnalplotsgeneral(diurnalDF,meta, parks, filename):

        fig  = plt.figure(figsize=(30, 12))

        # loop over every curve to draw 
        i = 0
        for key in parks.keys():
            # if there is only one category to find 
            index = parks[key]                
            # make sure that there was data found satisfying the criteria 
            if index.shape[0] >0 :
                lab = '%s, %s/%s sensors (%2.1f %%)'%(key, index.shape[0], meta.sensornumber.shape[0], index.shape[0]/float(meta.sensornumber.shape[0])*100 )
                plt.subplot(1,2,1)
                diurnalDF.set_index("hour").groupby(level=0).mean()[index].mean(axis=1).plot(linewidth = 3,
                                                                                                 yerr= diurnalDF.set_index("hour").groupby(level=0).mean()[index].std(axis=1),
                                                                                                 label = lab, 
                                                                                                 alpha = .7)

                plt.text(15.5, diurnalDF.set_index("hour").groupby(level=0).mean()[index].mean(axis=1).max()+.3*i,
                 '%2.1f'%diurnalDF.set_index("hour").groupby(level=0).mean()[index].mean(axis=1).max(),
                 bbox=dict(facecolor='white', edgecolor = '#636363')
                 )
                plt.text(5.5, diurnalDF.set_index("hour").groupby(level=0).mean()[index].mean(axis=1).min(),
                 '%2.1f'%diurnalDF.set_index("hour").groupby(level=0).mean()[index].mean(axis=1).min(),
                 bbox=dict(facecolor='white', edgecolor = '#636363')
                 )
                      
                #plt.hold(True)
                i = i+1

            else : 
                print 'skipping plot %s'%title
            #annotate maximum and minimum
      
        title = 'Daily Cycle'
        plt.title(title)
        plt.ylabel('Temperature in $^\circ $F')
        plt.xlabel('Hour')
        plt.legend(bbox_to_anchor = (.5, -.28),
                    loc=8,
                   borderaxespad=0.)
        #plt.ylim([70,96])
        plt.xlim([0,23])
        plt.savefig(filename, format = 'eps', dpi = 600, 
                    bbox_inches='tight')
        plt.show()

# %%
diurnalDF =  tempDF*9/5.+32
diurnalDF["hour"] = tempDF.index.hour
diurnalDF.set_index("hour")

parks = {'Wilcox': np.array(WilcoxSensors), 
         'Birmingham': np.array(BirminghamSensors), 
}
filename = './plots/diurnal%s.eps'%(parks.keys())
diurnalplotsgeneral(diurnalDF,meta,  parks, filename)
# Out:
# /Users/annascott2/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):

# %%
date_spec = {'Date': [ 2]}
frames = []
i = 0
files = {'./data/stationdata/Birm20102015.csv'}
for file in files:
    data = pd.read_csv(file, sep = ',', 
                              index_col=0,
                              parse_dates = date_spec, 
                              keep_date_col=True)
    data.TMIN = data.TMIN*.1
    data.TMAX = data.TMAX*.1
    data1 = data.copy()
    stations = set(data.STATION)
    #frames = []

    for station in stations: 
        tmax =  data[data.STATION==station].TMAX
        tmin = data1[data1.STATION==station].TMIN
        frames.append( tmax.combine_first(tmin))
        frames[i].name = station 
        i = i+1

        #    frames.append({station : tmax.combine_first(tmin)})

obsDF = pd.concat(frames, axis =1)
obsDF.values[obsDF.values <= -200] = 'NaN'
obsDF.columns = ['Temp']
obsDF
# Out:
#             Temp
# Date
# 2010-05-01  27.2
# 2010-05-02  26.1
# 2010-05-03  28.3
# 2010-05-04  30.0
# 2010-05-05  30.0
# 2010-05-06  31.1
# 2010-05-07  31.1
# 2010-05-08  25.6
# 2010-05-09  21.7
# 2010-05-10  15.0
# 2010-05-11  28.9
# 2010-05-12  30.0
# 2010-05-13  30.6
# 2010-05-14  30.6
# 2010-05-15  31.1
# 2010-05-16  26.7
# 2010-05-17  27.8
# 2010-05-18  28.3
# 2010-05-19  26.7
# 2010-05-20  29.4
# 2010-05-21  25.0
# 2010-05-22  31.7
# 2010-05-23  32.8
# 2010-05-24  32.8
# 2010-05-25  27.8
# 2010-05-26  30.0
# 2010-05-27  31.1
# 2010-05-28  31.7
# 2010-05-29  27.8
# 2010-05-30  25.6
# ...          ...
# 2015-08-31  28.9
# 2015-09-01  31.7
# 2015-09-02  32.2
# 2015-09-03  33.3
# 2015-09-04  33.3
# 2015-09-05  32.8
# 2015-09-06  31.7
# 2015-09-07  31.1
# 2015-09-08  30.6
# 2015-09-09  31.1
# 2015-09-10  28.9
# 2015-09-11  30.6
# 2015-09-12  25.6
# 2015-09-13  23.9
# 2015-09-14  25.6
# 2015-09-15  27.2
# 2015-09-16  28.9
# 2015-09-17  27.8
# 2015-09-18  30.6
# 2015-09-19  31.7
# 2015-09-20  31.7
# 2015-09-21  23.9
# 2015-09-22  30.0
# 2015-09-23  29.4
# 2015-09-24  30.0
# 2015-09-25  26.7
# 2015-09-26  25.6
# 2015-09-27  23.9
# 2015-09-28  24.4
# 2015-09-29  30.6
#
# [1978 rows x 1 columns]

# %%
obsDF.Temp.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-102b7e960734> in <module>()
# ----> 1 obsDF.Temp.plot()
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2517                  yerr=yerr, xerr=xerr,
#    2518                  label=label, secondary_y=secondary_y,
# -> 2519                  **kwds)
#    2520
#    2521
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2322         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2323
# -> 2324     plot_obj.generate()
#    2325     plot_obj.draw()
#    2326     return plot_obj.result
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     912         self._compute_plot_data()
#     913         self._setup_subplots()
# --> 914         self._make_plot()
#     915         self._add_table()
#     916         self._make_legend()
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1623             kwds['label'] = label
#    1624
# -> 1625             newlines = plotf(ax, x, y, style=style, column_num=i, **kwds)
#    1626             self._add_legend_handle(newlines[0], label, index=i)
#    1627
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(ax, x, data, style, **kwds)
#    1660             # accept x to be consistent with normal plot func,
#    1661             # x is not passed to tsplot as it uses data.index as x coordinate
# -> 1662             lines = tsplot(data, plotf, ax=ax, style=style, **kwds)
#    1663             return lines
#    1664         return _plot
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tseries/plotting.pyc in tsplot(series, plotf, **kwargs)
#      61
#      62     # set date formatter, locators and rescale limits
# ---> 63     format_dateaxis(ax, ax.freq)
#      64
#      65     # x and y coord info
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tseries/plotting.pyc in format_dateaxis(subplot, freq)
#     220     subplot.xaxis.set_major_formatter(majformatter)
#     221     subplot.xaxis.set_minor_formatter(minformatter)
# --> 222     pylab.draw_if_interactive()
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/IPython/utils/decorators.pyc in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_macosx.pyc in draw_if_interactive()
#     235         figManager =  Gcf.get_active()
#     236         if figManager is not None:
# --> 237             figManager.canvas.invalidate()
#     238
#     239
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'invalidate'

# %%
fig  = plt.figure(figsize=(25, 10))
ax = plt.plot(obsDF.index[-112:], (obsDF.Temp['2015-06-10':'2015-09-29']*9/5.+32), linewidth= 3)
plt.ylabel('Temperature in $^\circ $F')
plt.savefig('bhamdailytemp.eps' , format = 'eps', dpi = 600, 
                    bbox_inches='tight')

# %%
fig  = plt.figure(figsize=(15, 15))
(obsDF.Temp['2015-06-10':'2015-08-20']*9/5.+32).plot(linewidth = 3)
plt.ylabel('Temperature in $^\circ $F')
#plt.xlabel('Date')
plt.title('Birmingham Temperature')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., ncol = 3)
plt.savefig('bhamdailytemp.eps' , format = 'eps', dpi = 600, 
                    bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-2bda5039e985> in <module>()
#       1 fig  = plt.figure(figsize=(15, 15))
# ----> 2 (obsDF.Temp['2015-06-10':'2015-08-20']*9/5.+32).plot(linewidth = 3)
#       3 plt.ylabel('Temperature in $^\circ $F')
#       4 #plt.xlabel('Date')
#       5 plt.title('Birmingham Temperature')
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2517                  yerr=yerr, xerr=xerr,
#    2518                  label=label, secondary_y=secondary_y,
# -> 2519                  **kwds)
#    2520
#    2521
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2322         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2323
# -> 2324     plot_obj.generate()
#    2325     plot_obj.draw()
#    2326     return plot_obj.result
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     912         self._compute_plot_data()
#     913         self._setup_subplots()
# --> 914         self._make_plot()
#     915         self._add_table()
#     916         self._make_legend()
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1623             kwds['label'] = label
#    1624
# -> 1625             newlines = plotf(ax, x, y, style=style, column_num=i, **kwds)
#    1626             self._add_legend_handle(newlines[0], label, index=i)
#    1627
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(ax, x, data, style, **kwds)
#    1660             # accept x to be consistent with normal plot func,
#    1661             # x is not passed to tsplot as it uses data.index as x coordinate
# -> 1662             lines = tsplot(data, plotf, ax=ax, style=style, **kwds)
#    1663             return lines
#    1664         return _plot
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tseries/plotting.pyc in tsplot(series, plotf, **kwargs)
#      61
#      62     # set date formatter, locators and rescale limits
# ---> 63     format_dateaxis(ax, ax.freq)
#      64
#      65     # x and y coord info
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/pandas/tseries/plotting.pyc in format_dateaxis(subplot, freq)
#     220     subplot.xaxis.set_major_formatter(majformatter)
#     221     subplot.xaxis.set_minor_formatter(minformatter)
# --> 222     pylab.draw_if_interactive()
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/IPython/utils/decorators.pyc in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /Users/ascott47/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_macosx.pyc in draw_if_interactive()
#     235         figManager =  Gcf.get_active()
#     236         if figManager is not None:
# --> 237             figManager.canvas.invalidate()
#     238
#     239
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'invalidate'

# %%
fig  = plt.figure(figsize=(12, 6))
diurnalDF =  obsDF*9/5.+32
diurnalDF["month"] = obsDF.index.month
diurnalDF["year"]  = obsDF.index.year
for month in [6,7,8]: 
    ax =diurnalDF[(diurnalDF.index.month==month)].groupby("year").mean()['Temp'].plot(linewidth = 3, 
                                                                                       yerr = diurnalDF[(diurnalDF.index.month==6)].groupby("year").std()['Temp'])
plt.legend(['June', 'July', 'August'])
plt.ylabel('Temperature in $^\circ $F')
plt.xlabel('Year')
plt.title('Average Birmingham Summer Month Temperatures')
plt.xlim([2009,2016])
ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%d'))
#diurnalDF.set_index("month").groupby(level = 0).mean()[5:6]
filename = './plots/bhamsummermonthtemps.eps'
plt.savefig(filename , format = 'eps', dpi = 600, 
                    bbox_inches='tight')

# %%
import matplotlib.dates as mdates
fig  = plt.figure(figsize=(12, 6))
diurnalDF =  obsDF*9/5.+32
diurnalDF["month"] = obsDF.index.month
diurnalDF["year"]  = obsDF.index.year
ax = diurnalDF[np.logical_or(diurnalDF.index.month==6, (diurnalDF.index.month==7), (diurnalDF.index.month==8))].groupby("year").mean()['Temp'].plot(linewidth = 3, 
                                                                                       yerr = diurnalDF[np.logical_or(diurnalDF.index.month==6, (diurnalDF.index.month==7), (diurnalDF.index.month==8))].groupby("year").std()['Temp'])
plt.ylabel('Temperature in $^\circ $F')
plt.xlabel('Year')
plt.title('Average Birmingham Summer Temperature')
plt.xlim([2009,2016])
#diurnalDF.set_index("month").groupby(level = 0).mean()[5:6]
filename = './plots/bhamsummertemps.eps'

ax.xaxis.set_major_formatter(plt.FormatStrFormatter('%d'))
plt.savefig(filename , format = 'eps', dpi = 600, 
                    bbox_inches='tight')

# %%
diurnalDF =  tempDF*9/5.+32
diurnalDF["hour"] = tempDF.index.hour
diurnalDF.set_index("hour")

parks = {#'Wilcox': np.array(WilcoxSensors), 
         #'Birmingham': np.array(BirminghamSensors), 
         'BAMAkids': np.array([27]), 
         'Outside BAMA Kids': np.array([5])
         
}
filename = './plots/diurnal%s.eps'%(parks.keys())
diurnalplotsgeneral(diurnalDF,meta,  parks, filename)

# %%
matplotlib.rcParams.update({'font.size': 24})
